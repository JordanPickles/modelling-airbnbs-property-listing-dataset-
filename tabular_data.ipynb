# %%
import pandas as pd
import ast
from ast import literal_eval

# %%
df = pd.read_csv('./airbnb-property-listings/tabular_data/listing.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988 entries, 0 to 987
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    988 non-null    object
#  1   Category              988 non-null    object
#  2   Title                 988 non-null    object
#  3   Description           900 non-null    object
#  4   Amenities             988 non-null    object
#  5   Location              988 non-null    object
#  6   guests                969 non-null    object
#  7   beds                  945 non-null    float64
#  8   bathrooms             888 non-null    float64
#  9   Price_Night           988 non-null    int64
#  10  Cleanliness_rating    890 non-null    float64
#  11  Accuracy_rating       890 non-null    float64
#  12  Communication_rating  890 non-null    float64
#  13  Location_rating       890 non-null    float64
#  14  Check-in_rating       890 non-null    float64
# ...

# %%
df = df.dropna(subset = ["Cleanliness_rating", "Accuracy_rating", "Communication_rating", "Location_rating", "Check-in_rating", "Value_rating"])
df
# Out:
#                                        ID    Category  \
# 0    f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1    1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2    d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3    ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 5    cfe479b9-c8f8-44af-9bc6-46ede9f14bb5  Treehouses
# ..                                    ...         ...
# 982  cfbc88da-e88c-415a-b397-108d0948c4ba  Beachfront
# 983  4fea5054-f999-4c07-addc-67e4d893deab  Beachfront
# 984  282118e2-049e-4d9f-b2f2-b47477881b07  Beachfront
# 985  9ebf9cec-624e-480e-8704-dffa7cb1fe51  Beachfront
# 987  d2b06c80-c643-485d-a24b-15d0811a3166  Beachfront
#
#                                                  Title  \
# 0                    Red Kite Tree Tent - Ynys Affalon
# 1       Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                          Cabane Entre Les Pins\n🌲🏕️🌲
# 3     Tree Top Cabin with log burner & private hot tub
# ...

# %%
df.dropna(subset = ['Description'])
df['Description'] = df['Description'].astype(str)
df['Description'] = df['Description'].str.replace('About this space', '')
df['Description'] = df['Description'].str.replace('"', '')
df['Description'] = df['Description'].str.split(",")
df['Description'] = df['Description'].apply(lambda x: [i for i in x if i != ''])
df['Description'] = df['Description'].apply(lambda x: ''.join(x))
print(df['Description'][2])
# Out:
# ['' 'Rustic cabin between the pines 3 meters high and 28 square meters on the banks of the Austreberth River 🌲🏕️🌲' 'The space' The space\nOur cabin between the pines is a great alternative for those looking for contact with nature and want to rest enjoy together or have fun with family or friends. With 3 meters high and 28 square meters it accommodates 4 people. Located on a 1.2 hectare property by the river Austreberthe our rustic treehouse shares the space with our garden rabbits and dumplings as well as wild dumplings and our beloved khenty mare who loves apples and carrots. A tranquil retreat with efficient thermal insulation and heaters for the colder days. Equipped with a double bed sofa bed kitchen  duvet and toilet.\n\n\nWe provide:\nTowels\nBed linens and pillows\nKitchen detergent and bathroom soap\nPaper towels & toilet paper\nCooking utensils\nCoffee tea salt and pepper herbs of provence\nWhat to do in the area's guide\n\nI'll follow us on Instagram @entreespins 'Guest ac
# ...

# %%
df['Description'] = df['Description'].apply(lambda x: ast.literal_eval(x))

# Remove empty quotes and "About this space" prefix from the lists
df['Description'] = df['Description'].apply(lambda x: [i.replace('"', '').replace('About this space', '') for i in x if i != ''])

# Join the list items with a whitespace
df['Description'] = df['Description'].apply(lambda x: ' '.join(x))

# Remove records with a missing description
df = df[df['Description'].notnull()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [73], line 1
# ----> 1 df['Description'] = df['Description'].apply(lambda x: ast.literal_eval(x))
#       3 # Remove empty quotes and "About this space" prefix from the lists
#       4 df['Description'] = df['Description'].apply(lambda x: [i.replace('"', '').replace('About this space', '') for i in x if i != ''])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# ...

# %%
df['Description'] = df['Description'].str.replace('About this space', '')
df['Description'] = df['Description'].apply(lambda x: [item for item in eval(str(x)) if item != ''])
df['Description'] = df['Description'].apply(lambda x: ''.join(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [127], line 2
#       1 df['Description'] = df['Description'].str.replace('About this space', '')
# ----> 2 df['Description'] = df['Description'].apply(lambda x: [item for item in eval(str(x)) if item != ''])
#       3 df['Description'] = df['Description'].apply(lambda x: ''.join(x))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# ...
